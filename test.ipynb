# %%
import torch

from args import *
from model_head import *
from dataloader_voc import *
from loss_metric import *

# %%
to_pil = transforms.ToPILImage()

# %%
model = ModelDisigner()
model = model.to(device)
model.load_state_dict(torch.load('pathignore/weights/test2.pth'))
# Out:
# <All keys matched successfully>

# %%
def save_img(object, i):
    for batch in range(BATCH_SIZE):
        print(object.shape)
        imgs = object[batch][0][1]
        img = (imgs > 0.5).float()
        print(imgs.shape)
        img = to_pil(img)
        img.save("../rec_siam_unet/test_output/frame%d_perd.png" % i)
        print('save!!!', i)

def save_img1(object, i):
    for batch in range(BATCH_SIZE):
        print(object.shape)
        imgs = object[batch][0][1]
        img = (imgs > 0.5).float()
        print(imgs.shape)
        img = to_pil(img)
        img.save("../rec_siam_unet/test_output/frame%d_mask.png" % i)
        print('save!!!', i)

# %%
for i, data in enumerate(train_loader):
    target, searchs, labels, depths, score_labels = data
    target, searchs, labels, depths, score_labels \
    = target.to(device), searchs.to(device), labels.to(device), depths.to(device), score_labels.to(device)
    pred_score, pred_mask = model(target, searchs)
    save_img(pred_mask.cpu(), i)
    save_img1(labels.cpu(), i)
# Out:
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 0
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 0
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 0
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 0
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 1
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 1
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 1
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 1
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 2
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 2
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 2
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 2
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 3
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 3
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 3
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 3
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 4
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 4
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 4
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 4
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 5
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 5
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 5
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 5
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 6
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 6
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 6
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 6
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 7
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 7
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 7
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 7
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 8
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 8
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 8
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 8
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 9
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 9
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 9
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 9
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 10
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 10
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 10
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 10
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 11
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 11
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 11
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 11
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 12
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 12
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 12
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 12
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 13
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 13
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 13
# torch.Size([2, 1, 2, 128, 128])
# torch.Size([128, 128])
# save!!! 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a28ca345c558> in <module>
#       3     target, searchs, labels, depths, score_labels \
#       4     = target.to(device), searchs.to(device), labels.to(device), depths.to(device), score_labels.to(device)
# ----> 5     pred_score, pred_mask = model(target, searchs)
#       6     save_img(pred_mask.cpu(), i)
#       7     save_img1(labels.cpu(), i)
#
# KeyboardInterrupt:
